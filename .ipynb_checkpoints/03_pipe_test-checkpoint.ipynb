# %% [markdown]
# # Import Data

# %%
from functions import data_clean

# %%
data = data_clean()

# %%
data.head()
# Out:
#         Date   Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0 2013-01-01  1115.0        2.0    0.0        0.0   0.0    0.0            a
# 1 2013-01-01   379.0        2.0    0.0        0.0   0.0    0.0            a
# 2 2013-01-01   378.0        2.0    0.0        0.0   0.0    0.0            a
# 3 2013-01-01   377.0        2.0    0.0        0.0   0.0    0.0            a
# 4 2013-01-01   376.0        2.0    0.0        0.0   0.0    0.0            a
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0            1.0         d          c               5350.0
# 1            1.0         d          a               6630.0
# 2            1.0         a          c               2140.0
# 3            1.0         a          c                100.0
# 4            1.0         a          a                160.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        1.0                    2013.0     1.0
# 1                        1.0                    2013.0     0.0
# 2                        8.0                    2012.0     0.0
# 3                        6.0                    2010.0     1.0
# 4                        8.0                    2012.0     0.0
#
#    Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0             22.0           2012.0  Mar,Jun,Sept,Dec
# 1              NaN              NaN               NaN
# 2              NaN              NaN               NaN
# 3             18.0           2010.0   Feb,May,Aug,Nov
# 4              NaN              NaN               NaN

# %% [markdown]
# # Feature Engineering

# %%
from functions import feature_engineering

# %%
data_feat = feature_engineering(data)

# %%
data_feat.head()
# Out:
#             Store   Sales  Customers  Open  Promo  SchoolHoliday  \
# Date
# 2013-01-01  353.0  3139.0      820.0   1.0    0.0            1.0
# 2013-01-01  335.0  2401.0      482.0   1.0    0.0            1.0
# 2013-01-01  512.0  2646.0      625.0   1.0    0.0            1.0
# 2013-01-01  494.0  3113.0      527.0   1.0    0.0            1.0
# 2013-01-01  530.0  2907.0      532.0   1.0    0.0            1.0
#
#             CompetitionDistance  state_holiday  winter  spring  ...  \
# Date                                                            ...
# 2013-01-01                900.0            1.0     1.0     0.0  ...
# 2013-01-01                 90.0            1.0     1.0     0.0  ...
# 2013-01-01                590.0            1.0     1.0     0.0  ...
# 2013-01-01               1260.0            1.0     1.0     0.0  ...
# 2013-01-01              18160.0            1.0     1.0     0.0  ...
#
#             Assortment_c  competition_active  Promo2_active  dayofweek  \
# Date
# 2013-01-01             0                 1.0            0.0          1
# 2013-01-01             0                 1.0            0.0          1
# 2013-01-01             0                 1.0            0.0          1
# 2013-01-01             0                 1.0            0.0          1
# 2013-01-01             1                 1.0            0.0          1
#
#             quarter  month  year  dayofyear  dayofmonth  weekofyear
# Date
# 2013-01-01        1      1  2013          1           1           1
# 2013-01-01        1      1  2013          1           1           1
# 2013-01-01        1      1  2013          1           1           1
# 2013-01-01        1      1  2013          1           1           1
# 2013-01-01        1      1  2013          1           1           1
#
# [5 rows x 28 columns]

# %% [markdown]
# # Prediction

# %%
from functions import split_x_y

# %%
X,y = split_x_y(data_feat, label='Sales')

# %%
from functions import scaler

# %%
X_scaled = scaler(X, mode='train', scaler=None)

# %%
from functions import predict

# %%
predict(X_scaled, y)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-23-f241d2e18b0e> in <module>
# ----> 1 predict(X_scaled, y)
#
# ~/git/Minicomp_Team3/functions.py in predict(X, y)
#     146                             max_depth=6)
#     147
# --> 148     model.fit(X, y)
#     149     preds = model.predict(X)
#     150
#
# ~/opt/anaconda3/envs/minicomp/lib/python3.6/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     542                               evals_result=evals_result, obj=obj, feval=feval,
#     543                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 544                               callbacks=callbacks)
#     545
#     546         if evals_result:
#
# ~/opt/anaconda3/envs/minicomp/lib/python3.6/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     210                            evals=evals,
#     211                            obj=obj, feval=feval,
# --> 212                            xgb_model=xgb_model, callbacks=callbacks)
#     213
#     214
#
# ~/opt/anaconda3/envs/minicomp/lib/python3.6/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      73         # Skip the first update if it is a recovery step.
#      74         if version % 2 == 0:
# ---> 75             bst.update(dtrain, i, obj)
#      76             bst.save_rabit_checkpoint()
#      77             version += 1
#
# ~/opt/anaconda3/envs/minicomp/lib/python3.6/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1367             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1368                                                     ctypes.c_int(iteration),
# -> 1369                                                     dtrain.handle))
#    1370         else:
#    1371             pred = self.predict(dtrain, output_margin=True, training=True)
#
# ~/opt/anaconda3/envs/minicomp/lib/python3.6/site-packages/xgboost/core.py in _check_call(ret)
#     188     """
#     189     if ret != 0:
# --> 190         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     191
#     192
#
# XGBoostError: [11:13:54] /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/data/data.cc:373: Check failed: labels_.Size() == num_row_ (452638 vs. 12221226) : Size of labels must equal to number of rows.
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x0000001a1722861e dmlc::LogMessageFatal::~LogMessageFatal() + 110
#   [bt] (1) 2   libxgboost.dylib                    0x0000001a1726d999 xgboost::MetaInfo::Validate(int) const + 1193
#   [bt] (2) 3   libxgboost.dylib                    0x0000001a172d85e6 xgboost::LearnerImpl::ValidateDMatrix(xgboost::DMatrix*) const + 54
#   [bt] (3) 4   libxgboost.dylib                    0x0000001a172c78dc xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 268
#   [bt] (4) 5   libxgboost.dylib                    0x0000001a17220bea XGBoosterUpdateOneIter + 154
#   [bt] (5) 6   libffi.7.dylib                      0x0000000104d67ead ffi_call_unix64 + 85
#   [bt] (6) 7   ???                                 0x00007ffeeb9c8ca0 0x0 + 140732851326112
